# %% [markdown]
# # Basic statistics
#
# Let's explore how Desbordante can help you with collecting basic statistics (min, max, mean, etc.).

# %% [markdown]
# # Install necessary python dependencies

# %%
# !pip install desbordante==2.3.2
# !pip install pandas
# Out:
# Collecting desbordante==2.3.2
#   Downloading desbordante-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (19 kB)
# Downloading desbordante-2.3.2-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.0/4.0 MB 32.5 MB/s eta 0:00:00
# Installing collected packages: desbordante
# Successfully installed desbordante-2.3.2
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (2.2.2)
# Requirement already satisfied: numpy>=1.23.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.0.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)

# %% [markdown]
# # Import desbordante and pandas libraries

# %%
import desbordante as db
import pandas as pd

# %% [markdown]
# # Download dataset

# %%
# !wget -q https://raw.githubusercontent.com/Desbordante/desbordante-core/main/examples/datasets/Workshop.csv

# %% [markdown]
# # Start exploring

# %% [markdown]
# Take a look at the source data.

# %%
dataset = pd.read_csv("Workshop.csv")
dataset
# Out:
#                                        id      worker_name supervisor_surname  \
# 0    404f50cb-caf0-4974-97f9-9463434537e1   Jennifer Moore        Galen Calla
# 1    b5e38281-9c09-49bf-91f5-c55397df4d43       Edward Lee      Carrie Silvia
# 2    972b299d-2f27-4d6d-81d2-8effbc543bf1        Brian Lee      Shena Desiree
# 3    3241fb48-5a15-4638-bd68-d915834a3f89   Kenneth Turner        Paul Jeffry
# 4    9cbb9026-f157-4a01-aace-a42b05ab2a28   Betty Campbell    Addyson Aaliyah
# ..                                    ...              ...                ...
# 940  9cd700bc-b3d9-439d-afe9-945c2a20bc37    Richard Lopez        Galen Calla
# 941  cc199ff4-453a-4ae5-9fbd-b45d72fa952a  Helen Rodriguez      Carrie Silvia
# 942  de650347-880a-42a2-88c9-4329f26fb912      Karen White      Carrie Silvia
# 943  ae604e24-e040-4d50-b685-5b4897ab9ae9    Charles Smith      Shena Desiree
# 944  d5cb954a-e942-47ae-9b62-b57f7a84c2db        Jeff King      Carrie Silvia
#
#           workshop  salary                   job_post
# 0      Yogatacular     980    Client Solution Analyst
# 1      MonsterWorq     905  Front-End Loader Operator
# 2    Talkspiration     700             Farm Assistant
# 3       Verbalthon     980    Client Solution Analyst
# 4       SpeakerAce     800            Physiotherapist
# ..             ...     ...                        ...
# 940    Yogatacular     845   Senior Financial Planner
# 941    MonsterWorq     465                Electrician
# 942    MonsterWorq     510       JavaScript Developer
# 943  Talkspiration     975              Store Manager
# 944    MonsterWorq     465                Electrician
#
# [945 rows x 6 columns]

# %% [markdown]
# Let's compute some simple statistics over a given dataset both over the whole data and column-wise.

# %%
data_stats = db.statistics.algorithms.Default()
data_stats.load_data(table=dataset)
data_stats.execute()

table_methods = [
        ["Columns with null", data_stats.get_columns_with_null()],
        ["Columns with all unique values", data_stats.get_columns_with_all_unique_values()],
        ["Number of columns", data_stats.get_number_of_columns()]
]

column_methods = {
    "Avg": data_stats.get_average,
    "Sum of squares": data_stats.get_sum_of_squares,
    "Median": data_stats.get_median,
    "Min": data_stats.get_min,
    "Max": data_stats.get_max,
    "Distinct": data_stats.get_number_of_distinct,
    "Corrected std": data_stats.get_corrected_std,
    "Min chars in a row": data_stats.get_min_number_of_chars,
    "Max chars in a row": data_stats.get_max_number_of_chars,
    "Min words in a row": data_stats.get_min_number_of_words,
    "Max words in a row": data_stats.get_max_number_of_words,
    "Char vocabulary": data_stats.get_vocab,
    "Word vocabulary": data_stats.get_words
}

# %% [markdown]
# Visualize the table statistics using pandas DataFrame.

# %%
columns_names = ["Metrics", "Value"]
df = pd.DataFrame(table_methods, columns=columns_names)
df
# Out:
#                           Metrics   Value
# 0               Columns with null      []
# 1  Columns with all unique values  [0, 1]
# 2               Number of columns       6

# %% [markdown]
# Then, take a look at some statistics over each column.

# %%
# Compute overall number of columns
num_cols = data_stats.get_number_of_columns()

# Gather column statistics for every column
column_stats = []
for i in range(num_cols):
    col_stats = {}
    # For every method given...
    for description, method in column_methods.items():
        #... compute stats over the column given a column number...
        res = method(i)
        #... if there are results, then collect the statistic.
        if res is not None:
            col_stats[description] = res
    column_stats.append(col_stats)

# Display the result
df_column_stats = pd.DataFrame(column_stats).fillna('').T
pd.set_option('display.max_colwidth', 20)
df_column_stats
# Out:
#                                       0                    1  \
# Min                 0008f14d-e2a7-45...     Anthony Campbell
# Max                 fff1cd7a-04f9-48...       William Taylor
# Distinct                            945                  945
# Min chars in a row                 36.0                  8.0
# Max chars in a row                 36.0                 21.0
# Min words in a row                  1.0                  2.0
# Max words in a row                  1.0                  2.0
# Char vocabulary       -0123456789abcdef   ABCDEGHJKLMNPRS...
# Word vocabulary     {e776c703-b419-4...  {Paul, Elizabeth...
# Avg
# Sum of squares
# Median
# Corrected std
#
#                                       2                    3            4  \
# Min                     Addyson Aaliyah          MonsterWorq          465
# Max                       Shena Desiree          Yogatacular         2036
# Distinct                              6                    5           28
# Min chars in a row                 11.0                 10.0
# Max chars in a row                 15.0                 13.0
# Min words in a row                  2.0                  1.0
# Max words in a row                  2.0                  1.0
# Char vocabulary      ACDGJPSadefhiln...  AMSTVWYabceghikl...
# Word vocabulary     {Paul, Silvia, C...  {MonsterWorq, Sp...           {}
# Avg                                                            932.258201
# Sum of squares                                                894298474.0
# Median                                                              945.0
# Corrected std                                                  278.072046
#
#                                       5
# Min                 Client Solution ...
# Max                 Workshop Technician
# Distinct                             15
# Min chars in a row                 11.0
# Max chars in a row                 25.0
# Min words in a row                  1.0
# Max words in a row                  3.0
# Char vocabulary      -ACDEFJLMOPRSTW...
# Word vocabulary     {Client, JavaScr...
# Avg
# Sum of squares
# Median
# Corrected std

# %% [markdown]
# Is is also possible to just get all stats at once using a print-friendly format of a plain text.

# %%
print(data_stats.get_all_statistics_as_string())
# Out:
# Column num = 0
# max_num_words = 1
# min_num_words = 1
# num_chars = 34020
# num_uppercase_chars = 0
# type = String
# isCategorical = 0
# num_lowercase_chars = 11108
# count = 945
# quantile50 = 81aabb56-808c-48a1-b2a3-5d3f2e1a752f
# num_entirely_lowercase = 945
# num_entirely_uppercase = 0
# max_num_chars = 1
# num_digit_chars = 19132
# distinct = 945
# avg_chars = 36.000000
# min = 0008f14d-e2a7-4582-bf5e-89ce32b55606
# num_words = 945
# quantile25 = 4307ef5b-2e00-4316-b04c-debff4edc5c4
# max = fff1cd7a-04f9-486c-97de-d5d2c6ddb3cb
# quantile75 = c8539dda-ec0e-4c67-a2f4-2d201bb82171
# min_num_chars = 1
# num_non_letter_chars = 22912
# vocab = -0123456789abcdef
#
# Column num = 1
# max_num_words = 2
# min_num_words = 2
# num_chars = 12261
# num_uppercase_chars = 1890
# type = String
# isCategorical = 0
# num_lowercase_chars = 9426
# count = 945
# quantile50 = Kenneth King
# num_entirely_lowercase = 0
# num_entirely_uppercase = 0
# max_num_chars = 2
# num_digit_chars = 0
# distinct = 945
# avg_chars = 12.974603
# min = Anthony Campbell
# num_words = 1890
# quantile25 = Donna White
# max = William Taylor
# quantile75 = Patricia Gonzalez
# min_num_chars = 2
# num_non_letter_chars = 945
# vocab =  ABCDEGHJKLMNPRSTWYabcdefghiklmnoprstuvwyz
#
# Column num = 2
# max_num_words = 2
# min_num_words = 2
# num_chars = 11843
# num_uppercase_chars = 1890
# type = String
# isCategorical = 1
# num_lowercase_chars = 9008
# count = 945
# quantile50 = Galen Calla
# num_entirely_lowercase = 0
# num_entirely_uppercase = 0
# max_num_chars = 2
# num_digit_chars = 0
# distinct = 6
# avg_chars = 12.532275
# min = Addyson Aaliyah
# num_words = 1890
# quantile25 = Carrie Silvia
# max = Shena Desiree
# quantile75 = Paul Jeffry
# min_num_chars = 2
# num_non_letter_chars = 945
# vocab =  ACDGJPSadefhilnorsuvy
#
# Column num = 3
# max_num_words = 1
# min_num_words = 1
# num_chars = 10452
# num_uppercase_chars = 1300
# type = String
# isCategorical = 1
# num_lowercase_chars = 9152
# count = 945
# quantile50 = Talkspiration
# num_entirely_lowercase = 0
# num_entirely_uppercase = 0
# max_num_chars = 1
# num_digit_chars = 0
# distinct = 5
# avg_chars = 11.060317
# min = MonsterWorq
# num_words = 945
# quantile25 = SpeakerAce
# max = Yogatacular
# quantile75 = Verbalthon
# min_num_chars = 1
# num_non_letter_chars = 0
# vocab = AMSTVWYabceghiklnopqrstu
#
# Column num = 4
# median_ad = 100.000000
# geometric_mean = 893.289725
# median = 945.000000
# sum_of_squares = 894298474
# num_negatives = 0
# quantile75 = 1020
# type = Int
# mean_ad = 186.978103
# isCategorical = 0
# kurtosis = 2.859101
# count = 945
# quantile50 = 945
# num_zeros = 0
# avg = 932.258201
# distinct = 28
# STD = 278.072046
# skewness = 1.132442
# min = 465
# quantile25 = 800
# max = 2036
# sum = 880984
#
# Column num = 5
# max_num_words = 3
# min_num_words = 1
# num_chars = 17603
# num_uppercase_chars = 2226
# type = String
# isCategorical = 0
# num_lowercase_chars = 14152
# count = 945
# quantile50 = Physiotherapist
# num_entirely_lowercase = 0
# num_entirely_uppercase = 0
# max_num_chars = 3
# num_digit_chars = 0
# distinct = 15
# avg_chars = 18.627513
# min = Client Solution Analyst
# num_words = 2113
# quantile25 = JavaScript Developer
# max = Workshop Technician
# quantile75 = Service Technician
# min_num_chars = 1
# num_non_letter_chars = 1225
# vocab =  -ACDEFJLMOPRSTWacdeghijklmnoprstuvy

# %% [markdown]
# # Conclusion

# %% [markdown]
# As you have seen, gathering an insight is a straightforward process using Desbordante.
